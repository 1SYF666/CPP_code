# %% [markdown]
# ## python 脚本文件

# %% [markdown]
# ### 保存为文件

# %%
print("I'm hungry!")
# Out:
# I'm hungry!

# %% [markdown]
# ### 类

# %%
class Man:
    def __init__(self,name):
        self.name = name;
        print("Initialized!")
    def hello(self):
        print("Hello" + self.name + "!" )
    def goodbye(self):
        print("Good-bye "+ self.name + "!")
m = Man("David")
m.hello()
m.goodbye()
# Out:
# Initialized!
# HelloDavid!
# Good-bye David!

# %% [markdown]
# ## Numpy

# %%
import numpy as np
x = np.array([1.0,2.0,3.0])
print(x)
type(x)
# Out:
# [1. 2. 3.]
# numpy.ndarray

# %% [markdown]
# ### NumPy的算术运算

# %%
x = np.array([1.0,2.0,3.0])
y = np.array([2.0,4.0,6.0])
x+y
# Out:
# array([3., 6., 9.])

# %%
x/2.0
# Out:
# array([0.5, 1. , 1.5])

# %% [markdown]
# ### NumPy 的N维数组

# %%
A = np.array([[1,2],[3,4]])
print(A)
# Out:
# [[1 2]
#  [3 4]]

# %%
A.shape
# Out:
# (2, 2)

# %%
A.dtype
# Out:
# dtype('int32')

# %%
B = np.array([[3,0],[0,6]])
A+B
# Out:
# array([[ 4,  2],
#        [ 3, 10]])

# %%
print(A)
# Out:
# [[1 2]
#  [3 4]]

# %%
A*10
# Out:
# array([[10, 20],
#        [30, 40]])

# %% [markdown]
# ### 广播

# %%
A = np.array([[1,2],[3,4]])
B = np.array([10,20])
A*B
# Out:
# array([[10, 40],
#        [30, 80]])

# %% [markdown]
# ### 访问元素

# %%
X = np.array([[51,55],[14,19],[0,4]])
print(X)
# Out:
# [[51 55]
#  [14 19]
#  [ 0  4]]

# %%
X[0]
# Out:
# array([51, 55])

# %%
X[0][1]
# Out:
# 55

# %%
for row in X:
    print(row)
# Out:
# [51 55]
# [14 19]
# [0 4]

# %%
X = X.flatten()  # 将X转换为一维数组
print(X)
# Out:
# [51 55 14 19  0  4]

# %%
X[np.array([0,2,4])] # 获取索引为0 2 4 的元素
# Out:
# array([51, 14,  0])

# %%
X>15
# Out:
# array([ True,  True, False,  True, False, False])

# %%
X[X>15]
# Out:
# array([51, 55, 19])

# %% [markdown]
# ## Matplotlib

# %% [markdown]
# ### 绘制简单图形

# %%
import numpy as np
import matplotlib.pyplot as plt
# 生成数据
x = np.arange(0,6,0.1) # 以0.1为单位，生成0到6的数据
y1 = np.sin(x)
y2 = np.cos(x)
# 绘制图形
plt.plot(x,y1,label = "sin")
plt.plot(x,y2,linestyle = "--",label = "cos") # 用虚线绘制
plt.xlabel("x") # x轴标签
plt.ylabel("y") # y轴标签
plt.title("sin & cos") #标题
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread
img = imread('D:\Postgraduate\code\London.jpg') # 读入图像（设定合适的路径！）
plt.imshow(img)
plt.show()
